# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !pip install --force-reinstall tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached grpcio-1.63.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# ...
#   Using cached protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# ...
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 479.6/479.6 MB 595.8 kB/s eta 0:00:000:01m00:14
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 1.4 MB/s eta 0:00:00 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 737.4 kB/s eta 0:00:000:00:01
# Using cached grpcio-1.63.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.6 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 731.8 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 1.2 MB/s eta 0:00:0000:0100:010m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 1.2 MB/s eta 0:00:0000:0100:01
# ...

# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import tensorflow as tf
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/__init__.py:46
#      43 from tensorflow.python import tf2 as _tf2
#      44 _tf2.enable()
# ---> 46 from ._api.v2 import __internal__
#      47 from ._api.v2 import __operators__
#      48 from ._api.v2 import audio
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/_api/v2/__internal__/__init__.py:10
#       8 from . import autograph
#       9 from . import decorator
# ---> 10 from . import dispatch
#      11 from . import distribute
#      12 from . import eager_context
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/_api/v2/__internal__/dispatch/__init__.py:8
#       3 """Public API for tf.__internal__.dispatch namespace.
#       4 """
#       6 import sys as _sys
# ...
