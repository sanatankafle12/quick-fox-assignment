# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

# %%
x_arr = np.array([
    [1,3],
    [3,-1],
    [2,2]
])

y_arr = np.array([
    -2,
    4,
    1
])

# %%
def sum_of_squared_residual_error():
    pass
# Out:
# Least-squares solution:
# [ 1.11111111 -0.88888889]
# Sum of squared residual error:
# 0.5555555555555556

# %%
def pseudo_inverse():
    pass
